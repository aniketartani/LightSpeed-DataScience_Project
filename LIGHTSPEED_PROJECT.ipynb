# %% [markdown]
# # LightSpeed E-Cycles Case Study - Descriptive Statistics
# LightSpeed builds powerful, reliable electric bicycles that are masterfully designed to attract appreciative glances as you ride along. The task  was to identify the profile of the typical customer for each product offered by LightSpeed  Electric Bicycles Company.
#
# We decide to investigate whether there are differences across the product lines with respect to customer characteristics.
#
# We decide to collect data on individuals who purchased a e-bicycle at LightSpeed bicycle retail store during the prior three months.
#
#
#
# ### The team identifies the following customer variables to study:
#   - product purchased, FURY518,DRYFT AND RUSH;
#   - gender;
#   - age, in years;
#   - education, in years;
#   - relationship status, single or partnered;
#   - annual household income ;
#   - average number of times the customer plans to use the bicycle each week;
#   - average number of miles the customer expects to use cycling each week;
#   - and self-rated fitness on an 1-to-5 scale, where 1 is poor shape and 5 is excellent shape.

# %%
import numpy as np
import pandas as pd

# %%
mydata = pd.read_csv('college (1).csv')

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10470 entries, 0 to 10469
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        10470 non-null  object
#  1   Age            10470 non-null  int64
#  2   Gender         10470 non-null  object
#  3   Education      10470 non-null  int64
#  4   MaritalStatus  10470 non-null  object
#  5   Usage          10470 non-null  int64
#  6   Fitness        10470 non-null  int64
#  7   Income         10470 non-null  int64
#  8   Miles          10470 non-null  int64
# dtypes: int64(6), object(3)
# memory usage: 736.3+ KB

# %% [markdown]
# ## Data Preparation and Cleaning

# %%
mydata
# Out:
#        Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0      FURY518   18    Male         14        Single      3        4   29562
# 1      FURY518   19    Male         15        Single      2        3   31836
# 2      FURY518   19  Female         14     Partnered      4        3   30699
# 3      FURY518   19    Male         12        Single      3        3   32973
# 4      FURY518   20    Male         13     Partnered      4        2   35247
# ...        ...  ...     ...        ...           ...    ...      ...     ...
# 10465  FURY518   24    Male         14        Single      2        3   45480
# 10466  FURY518   24    Male         13     Partnered      3        2   42069
# 10467  FURY518   24  Female         16        Single      4        3   46617
# 10468  FURY518   25  Female         14     Partnered      3        3   48891
# 10469  FURY518   25    Male         14     Partnered      2        3   45480
#
#        Miles
# 0        112
# 1         75
# ...

# %%
mydata.describe(include="all")
# Out:
#         Product           Age Gender     Education MaritalStatus  \
# count     10470  10470.000000  10470  10470.000000         10470
# unique        3           NaN      2           NaN             2
# top     FURY518           NaN   Male           NaN     Partnered
# freq       4605           NaN   6049           NaN          6224
# mean        NaN     28.764183    NaN     15.575454           NaN
# std         NaN      6.904800    NaN      1.614006           NaN
# min         NaN     18.000000    NaN     12.000000           NaN
# 25%         NaN     24.000000    NaN     14.000000           NaN
# 50%         NaN     26.000000    NaN     16.000000           NaN
# 75%         NaN     33.000000    NaN     16.000000           NaN
# max         NaN     50.000000    NaN     21.000000           NaN
#
#                Usage       Fitness         Income         Miles
# count   10470.000000  10470.000000   10470.000000  10470.000000
# ...

# %%
mydata.mean()
# Out:
# Age             28.764183
# Education       15.575454
# Usage            3.459694
# Fitness          3.312703
# Income       53737.127125
# Miles          103.319484
# dtype: float64

# %%
mydata.std()
# Out:
# Age              6.904800
# Education        1.614006
# Usage            1.083508
# Fitness          0.957608
# Income       16453.112726
# Miles           51.789854
# dtype: float64

# %%
mydata.groupby('Product').mean()
# Out:
#                Age  Education     Usage   Fitness        Income       Miles
# Product
# DRYFT    28.935246  15.119852  3.067310  2.900028  49021.242261   87.917353
# FURY518  28.503149  15.034745  3.090337  2.961129  46360.218241   82.802172
# RUSH     29.020051  17.322099  4.774744  4.623294  75313.618601  166.763652

# %%
mydata.groupby('Product').std()
# Out:
#               Age  Education     Usage   Fitness        Income      Miles
# Product
# DRYFT    6.589533   1.212321  0.793626  0.624502   8571.288468  32.963448
# FURY518  7.167919   1.208898  0.779073  0.660747   9009.042519  28.734747
# RUSH     6.825614   1.619057  0.936541  0.660568  18264.322588  59.320426

# %% [markdown]
# ## Exploratory Analysis and Visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021954380580>,
# ...
#       dtype=object)

# %%
import seaborn as sns
sns.distplot(mydata["Age"],color="darkblue")

# %%
sns.distplot(mydata["Education"],color="darkblue")

# %%
sns.distplot(mydata["Miles"],color="darkblue")

# %%
sns.distplot(mydata["Fitness"],color="darkblue")

# %%
sns.distplot(mydata["Income"],color="darkblue")

# %%
sns.distplot(mydata["Usage"],color="darkblue")

# %%
import seaborn as sns

sns.boxplot(x="Gender", y="Age", data=mydata)

# %%
pd.crosstab(mydata['Product'],mydata['Gender'] )
# Out:
# Gender   Female  Male
# Product
# DRYFT      1702  1819
# FURY518    2307  2298
# RUSH        412  1932

# %%
pd.crosstab(mydata['Product'],mydata['MaritalStatus'] )
# Out:
# MaritalStatus  Partnered  Single
# Product
# DRYFT               2114    1407
# FURY518             2762    1843
# RUSH                1348     996

# %%
sns.countplot(x="Product", hue="Gender", data=mydata)

# %%
sns.countplot(x="Product", hue="MaritalStatus", data=mydata)

# %%
pd.pivot_table(mydata, index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'], aggfunc=len)
# Out:
#                      Age        Education          Fitness           Income  \
# MaritalStatus  Partnered Single Partnered Single Partnered Single Partnered
# Product Gender
# DRYFT   Female       881    821       881    821       881    821       881
#         Male        1233    586      1233    586      1233    586      1233
# FURY518 Female      1554    753      1554    753      1554    753      1554
#         Male        1208   1090      1208   1090      1208   1090      1208
# RUSH    Female       235    177       235    177       235    177       235
#         Male        1113    819      1113    819      1113    819      1113
#
#                           Miles            Usage
# MaritalStatus  Single Partnered Single Partnered Single
# Product Gender
# DRYFT   Female    821       881    821       881    821
#         Male      586      1233    586      1233    586
# FURY518 Female    753      1554    753      1554    753
# ...

# %%
pd.pivot_table(mydata,'Income', index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'])
# Out:
# MaritalStatus      Partnered        Single
# Product Gender
# DRYFT   Female  49772.465380  48949.618758
#         Male    49429.530414  47133.112628
# FURY518 Female  46093.862934  45632.505976
#         Male    49944.230960  43270.673394
# RUSH    Female  84925.893617  58516.000000
#         Male    81305.886792  68042.433455

# %%
pd.pivot_table(mydata,'Miles', index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'])
# Out:
# MaritalStatus    Partnered      Single
# Product Gender
# DRYFT   Female   93.885358   80.135201
#         Male     87.284672   91.179181
# FURY518 Female   75.008366   79.010624
#         Male     80.027318   99.608257
# RUSH    Female  215.063830  133.333333
#         Male    176.217430  147.282051

# %%
mydata.hist(by='Gender',column = 'Age')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002196152AE80>,
# ...
#       dtype=object)

# %%
mydata.hist(by='Gender',column = 'Income')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021961AC9610>,
# ...
#       dtype=object)

# %%
mydata.hist(by='Gender',column = 'Miles')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021961B951C0>,
# ...
#       dtype=object)

# %%
mydata.hist(by='Gender',column = 'Usage')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021961C5D8B0>,
# ...
#       dtype=object)

# %%
mydata.hist(by='MaritalStatus',column = 'Usage')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021961CF0C70>,
# ...
#       dtype=object)

# %%
mydata.hist(by='MaritalStatus',column = 'Miles')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021961CACE20>,
# ...
#       dtype=object)

# %%
mydata.hist(by='Product',column = 'Miles', figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021961EA2A90>,
# ...
#       dtype=object)

# %%
mydata.hist(by='Product',column = 'Usage', figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021962C13E20>,
# ...
#       dtype=object)

# %%
mydata.hist(by='Product',column = 'Income', figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021960DD5430>,
# ...
#       dtype=object)

# %%
mydata.hist(by='Product',column = 'Fitness', figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002196118F670>,
# ...
#       dtype=object)

# %%
mydata.hist(by='Product',column = 'Education', figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021961314FA0>,
# ...
#       dtype=object)

# %%
mydata.hist(by='Product',column = 'Age', figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000219613ECD30>,
# ...
#       dtype=object)

# %%
sns.pairplot(mydata)

# %%
sns.pairplot(mydata, hue='Product', diag_kind='hist')

# %%
sns.pairplot(mydata, kind='reg')

# %%
sns.pairplot(mydata, kind='reg', hue='Product')
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
corr = mydata.corr()
corr
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.278003  0.011261  0.058147  0.510688  0.034624
# Education  0.278003   1.000000  0.394490  0.410672  0.625475  0.306330
# Usage      0.011261   0.394490  1.000000  0.668542  0.519306  0.759117
# Fitness    0.058147   0.410672  0.668542  1.000000  0.534930  0.785384
# Income     0.510688   0.625475  0.519306  0.534930  1.000000  0.543572
# Miles      0.034624   0.306330  0.759117  0.785384  0.543572  1.000000

# %%
sns.heatmap(corr, annot=True)

# %%
# Simple Linear Regression


#Load function from sklearn
from sklearn import linear_model

# Create linear regression object
regr = linear_model.LinearRegression()

y = mydata['Miles']
x = mydata[['Usage','Fitness']]

# Train the model using the training sets
regr.fit(x,y)
# Out:
# LinearRegression()

# %%
regr.coef_
# Out:
# array([20.22851801, 27.17391526])

# %%
regr.intercept_
# Out:
# -56.68411508289411

# %% [markdown]
# # MilesPredicted = -56.74 + 20.21*Usage + 27.20*Fitness
